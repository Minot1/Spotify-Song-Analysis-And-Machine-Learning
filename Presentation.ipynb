# %% [markdown]
# <h1><b><center> CS210 PROJECT </center></b></h1>
# <h2><center>Subject: Spotify Song and Genre Analysis, and Popularity Prediction</center></h2>
# <h4><center>Project Members: Taner Dinçer (26899)<br>
#         <br>Project ID: 69</center></h4>
#         <br><br>
# <center><a href:"https://www.kaggle.com/yamaerenay/spotify-dataset-19212020-160k-tracks">Kaggle Dataset</a></center><br>

# %% [markdown]
# # Introduction

# %% [markdown]
# Here is the first 5 rows of our dataset, it includes approximately 174,000 rows(songs) and 18 features.

# %% [markdown]
# ![dataframe.PNG](data:image/png;base64,...)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Here is the histograms for continuous features.

# %% [markdown]
# ![vv.PNG](data:image/png;base64,...)

# %% [markdown]
# This is the correlation graph of the features. The most noticeable ones are energy-loudness, valence-danceability and energy-year.

# %% [markdown]
# ![aa.PNG](data:image/png;base64,...)

# %% [markdown]
# This is the 10 most popular music genres with respect to duration of the songs. As you can see j-rap songs tend to be longer.

# %% [markdown]
# ![bba.PNG](data:image/png;base64,...)

# %% [markdown]
# Here are some important findings after some analysis of the most popular songs:
# >1) Danceability is significantly higher in popular songs.
#
# >2) Duration is significantly lower in popular songs, which generally means people love shorter songs.
#
# >3) Energy is higher in popular songs.
#
# >4) Explicitness is by far the most significant different one. Popular songs 100% explicit whereas other songs are 6% explicit.
#
# >5) Instrumentalness is lower in popular songs.
#
# >6) Tempo is higher in popular songs.
#
# >7) Year is very interesting, the most popular songs are released in either 2020 or 2021 whereas the other songs' mean is 1977, which means most popular songs are the newest ones.

# %% [markdown]
# And here are some important findings after some analysis on popular artists:
# >1) Popular artists tend to be less acoustic
#
# >2) Popular artists tend to have shorter songs
#
# >3) Popular artists tend to be more energetic
#
# >4) Popular artists tend to be less instrumental
#
# >5) Popular artists tend to be louder

# %% [markdown]
# # Statistical Analysis and Hypothesis Testing

# %% [markdown]
# In this part, a hypothesis testing was investigated and found that acousticness effect on popularity is statistically **insignificant**, with the details below:

# %% [markdown]
# Null Hypothesis ($H_0$): Acousticness is the same in popular songs.
#
# $H_0: \mu_{popular} = \mu = 0.4992$
#
# Alternate Hypothesis ($H_A$): Acousticness is significantly lower in popular songs.
#
# $H_A: \mu_{popular} < \mu = 0.4992$
#
# Significance level: 0.05
#
# $SE = \frac{\sigma}{\sqrt n} = \frac{0.2453}{10} = 0.0245$
#
# $z = \frac{\mu_a - \mu}{SE} = \frac{0.2659 - 0.4992}{0.3799} = -0.6141$
#
# From the Z-Table, our p-value is 0.27093

# %% [markdown]
# # Machine Learning

# %% [markdown]
# In this part, some models which predicts the popularity of a song with the other features was implemented and compared with model types, specifically Random Forest Regressor, AdaBoost Regressor and Decision Tree Regressor. They were compared with their metrics of $R^2$ score, mean absolute error and mean squared error.
#
# The related findings was as follows:

# %% [markdown]
# --- Random Forest Regressor ---
#
# 	R^2 score = 0.4536661376243727
# 	MAE score = 10.726500000000001
# 	MSE score = 248.18854699999997
#
# --- AdaBoost Regressor ---
#
#     R^2 score = 0.3630937896094304
#     MAE score = 11.83815942576517
# 	MSE score = 289.33375325622796
#
# --- Decision Tree Regressor ---
#
#     R^2 score = -0.2581447565378181
#     MAE score = 14.91
# 	MSE score = 571.55

# %% [markdown]
# After that, hyper parameters were tuned with the help of GridSearchCV module from sklearn library and gained a 5% increase in $R^2$ score. Related results:
#
# --- Old Random Forest Regressor ---
#
#     R^2 score = 0.4536661376243727
# 	MAE score = 10.726500000000001
# 	MSE score = 248.18854699999997
#
# --- Random Forest Regressor After Tuning ---
#
# 	R^2 score = 0.5013768180052355
# 	MAE score = 10.923603590445698
# 	MSE score = 254.90634254863627
